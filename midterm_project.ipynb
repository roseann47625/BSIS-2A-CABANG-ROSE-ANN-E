# %% [markdown]
# <a href="https://colab.research.google.com/github/roseann47625/BSIS-2A-CABANG-ROSE-ANN-E/blob/main/midterm_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop("Age", axis = 1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df_filna = df.fillna('n/a')

# %%
df_filna.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   n/a        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   n/a        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   n/a        S

# %%
df = df.dropna()

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 6                             McCarthy, Mr. Timothy J    male      0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female      1      1
# 11                           Bonnell, Miss. Elizabeth  female      0      0
#
#       Ticket     Fare Cabin Embarked
# 1   PC 17599  71.2833   C85        C
# 3     113803  53.1000  C123        S
# 6      17463  51.8625   E46        S
# 10   PP 9549  16.7000    G6        S
# 11    113783  26.5500  C103        S

# %%
df_sort = df.sort_values(by = 'Sex', ascending = False)

# %%
df_sort.head()
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 889          890         1       1            Behr, Mr. Karl Howell  male
# 456          457         0       1        Millet, Mr. Francis Davis  male
# 452          453         0       1  Foreman, Mr. Benjamin Laventall  male
# 449          450         1       1   Peuchen, Major. Arthur Godfrey  male
# 445          446         1       1        Dodge, Master. Washington  male
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 889      0      0  111369  30.0000  C148        C
# 456      0      0   13509  26.5500   E38        S
# 452      0      0  113051  27.7500  C111        C
# 449      0      0  113786  30.5000  C104        S
# 445      0      2   33638  81.8583   A34        S

# %%
df_grouped = df.groupby('Sex').agg({
    'Survived': 'mean'
})

# %%
df_grouped.head()
# Out:
#         Survived
# Sex
# female  0.936842
# male    0.420561

# %%
df_apply = df['Sex'] = df['Survived'].apply (lambda x: x*2)

# %%
df_apply.head()
# Out:
# 1     2
# 3     2
# 6     0
# 10    2
# 11    2
# Name: Survived, dtype: int64

# %%
df1 = pd.DataFrame({'key': ['age','gender'] , 'values' : [44, 'female']})
df2 = pd.DataFrame({'key': ['age','gender'] , 'values' : [32, 'male']})
merged_df = pd.merge(df1, df2, on = 'key')

# %%
merged_df.head()
# Out:
#       key values_x values_y
# 0     age       44       32
# 1  gender   female     male

# %%
pivot_df = df.pivot_table(values = 'Sex' , index = 'Survived', aggfunc = 'mean')

# %%
pivot_df.head()
# Out:
#           Sex
# Survived
# 0         0.0
# 1         2.0

# %%
import pandas as pd
import numpy as np

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Sex  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    2      1      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    2      1      0
# 6                              McCarthy, Mr. Timothy J    0      0      0
# 10                     Sandstrom, Miss. Marguerite Rut    2      1      1
# 11                            Bonnell, Miss. Elizabeth    2      0      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
Survived = df['Survived'].to_numpy()

# %%
mean_survived = np.mean(Survived)

# %%
print(mean_survived)
# Out:
# 0.6633663366336634

# %%
median_survived = np.median(Survived)

# %%
print(median_survived)
# Out:
# 1.0

# %%
std_survived = np.std(Survived)

# %%
print(std_survived)
# Out:
# 0.4725583985656128

# %%
total = np.sum(Survived)

# %%
print(total)
# Out:
# 134

# %%
import numpy as np
array = np.array([1,2,3,4,5,6,8])
np.median(array)
# Out:
# 4.0

# %%
np.median(array)
# Out:
# 4.0

# %%
np.min(array)
# Out:
# 1

# %%
np.max(array)
# Out:
# 8

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
sns.histplot(df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
plt.show()

# %%
df1 = sns.catplot(data=df ,col = "Sex",x = "Survived",kind = "count")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
df_h = df.groupby(['Name','Survived']).size().head(10)

# %%
(df_h.head())
# Out:
# Name                                             Survived
# Allen, Miss. Elisabeth Walton                    1           1
# Allison, Master. Hudson Trevor                   1           1
# Allison, Miss. Helen Loraine                     0           1
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  0           1
# Anderson, Mr. Harry                              1           1
# dtype: int64

# %%
top_5 = df_h.sort_values(ascending = True).head(5)

# %%
top_5.plot(kind='bar')
plt.title('Total Survived')
plt.xlabel('PassengerId')
plt.ylabel('Pclass')
plt.show()

# %%
df_n = df.groupby(['Survived']).size().head(10)

# %%
print(df_n)
# Out:
# Survived
# 0     68
# 1    134
# dtype: int64

# %%
df_n.plot(kind='pie')
plt.title('Total Survived')
plt.show()

# %%
df_n.plot(kind='line')
plt.title('PassengerId')
plt.show()

# %%
df_s = df.groupby(['Survived']).size().head(10)

# %%
df_s.plot(kind='pie')
plt.title('Pclass')
plt.show()
