# %% [markdown]
# <a href="https://colab.research.google.com/github/roseann47625/BSIS-2A-CABANG-ROSE-ANN-E/blob/main/Activity2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/roseann47625/BSIS-2A-CABANG-ROSE-ANN-E/main/SALARY_DATA.csv')

# %%
print(df)
# Out:
#     Employee ID     Name  Age Department  Salary
# 0             1    Alice   45         Hr   54000
# 1             2      Bob   52         It   78000
# 2             3  Charlie   37    Finance   66000
# 3             4    David   28  Markiting   72000
# 4             5      Eva   41      Sales   85000
# 5             6    Frank   53         It   90000
# 6             7    Grace   32    Finance   62000
# 7             8    Henry   25         Hr   40000
# 8             9      Ivy   48      Sales   94000
# 9            10     Jack   39  Markiting   70000
# 10           11    Karen   29         It   65000
# 11           12      Leo   44    Finance   86000
# 12           13     Mona   33         Hr   47000
# 13           14     Nina   51      Sales   88000
# 14           15    Oscar   36  Markiting   56000

# %%
salary = df['Salary']. to_numpy()

# %%
mean_salary = np.mean(salary)

# %%
print(mean_salary)
# Out:
# 70200.0

# %%
median_salary = np.median(salary)

# %%
print(median_salary)
# Out:
# 70000.0

# %%
std_salary = np.std(salary)

# %%
print(std_salary)
# Out:
# 15988.32907675679

# %%
total_salary = np.sum(salary)

# %%
print(total_salary)
# Out:
# 1053000

# %%
sns.histplot(df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.catplot(data=df , col = "Name" , x = "Salary", kind = "count")

# %%
df_h = df.groupby(['Name' , 'Salary']).size().head(10)

# %%
(df_h.head())
# Out:
# Name     Salary
# Alice    54000     1
# Bob      78000     1
# Charlie  66000     1
# David    72000     1
# Eva      85000     1
# dtype: int64

# %%
top_5 = df_h.sort_values(ascending = True).head(5)

# %%
top_5.plot(kind='bar')
plt.title('total salary')
plt.xlabel('Name')
plt.ylabel('Highest salary')
# Out:
# Text(0, 0.5, 'Highest salary')

# %%
df_h = df.groupby([ 'Department']).size().head(10)

# %%
print(df_h)
# Out:
# Department
# Finance      3
# Hr           3
# It           3
# Markiting    3
# Sales        3
# dtype: int64
